# %% [markdown]
# ### Importing Libraries, loading and viewing the data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('EPL_20_21.csv')
df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   532 non-null    object
#  1   Club                   532 non-null    object
#  2   Nationality            532 non-null    object
#  3   Position               532 non-null    object
#  4   Age                    532 non-null    int64
#  5   Matches                532 non-null    int64
#  6   Starts                 532 non-null    int64
#  7   Mins                   532 non-null    int64
#  8   Goals                  532 non-null    int64
#  9   Assists                532 non-null    int64
#  10  Passes_Attempted       532 non-null    int64
#  11  Perc_Passes_Completed  532 non-null    float64
#  12  Penalty_Goals          532 non-null    int64
#  13  Penalty_Attempted      532 non-null    int64
# ...

# %% [markdown]
# ### General Statistics

# %%
df.describe()
# Out:
#               Age     Matches      Starts         Mins       Goals  \
# count  532.000000  532.000000  532.000000   532.000000  532.000000
# mean    25.500000   19.535714   15.714286  1411.443609    1.853383
# std      4.319404   11.840459   11.921161  1043.171856    3.338009
# min     16.000000    1.000000    0.000000     1.000000    0.000000
# 25%     22.000000    9.000000    4.000000   426.000000    0.000000
# 50%     26.000000   21.000000   15.000000  1345.000000    1.000000
# 75%     29.000000   30.000000   27.000000  2303.500000    2.000000
# max     38.000000   38.000000   38.000000  3420.000000   23.000000
#
#           Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# count  532.000000        532.000000             532.000000     532.000000
# mean     1.287594        717.750000              77.823872       0.191729
# std      2.095191        631.372522              13.011631       0.850881
# ...

# %%
df.isna().sum()
# Out:
# Name                     0
# Club                     0
# Nationality              0
# Position                 0
# Age                      0
# Matches                  0
# Starts                   0
# Mins                     0
# Goals                    0
# Assists                  0
# Passes_Attempted         0
# Perc_Passes_Completed    0
# Penalty_Goals            0
# Penalty_Attempted        0
# xG                       0
# xA                       0
# Yellow_Cards             0
# Red_Cards                0
# dtype: int64

# %% [markdown]
# ### Creating the 'minutes per match' and 'goals per match' columns

# %%
df['MinsPerMatch'] = (df['Mins']/df['Matches']).astype(int)
df['GoalsPerMatch'] = (df['Goals']/df['Matches']).astype(float)
df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
# ...

# %%
Total_Goals = df['Goals'].sum()
Total_Goals
# Out:
# 986

# %%
Total_Penalty_Goals = df['Penalty_Goals'].sum()
Total_Penalty_Goals
# Out:
# 102

# %%
Total_Penalty_Attempts = df['Penalty_Attempted'].sum()
Total_Penalty_Attempts
# Out:
# 125

# %% [markdown]
# ### Penalties Missed vs Penalties Scored

# %%
plt.figure(figsize=(13,6))
penalty_not_scored = df['Penalty_Attempted'].sum() - Total_Penalty_Goals
data = [penalty_not_scored,Total_Penalty_Goals]
labels = ['Penalties Missed','Penalties Scored']
color = sns.color_palette('Set2')
plt.pie(data, labels=labels, colors=color, autopct='%.0f%%')
plt.show()

# %% [markdown]
# ### Unique Positions

# %%
df['Position'].unique()
# Out:
# array(['MF,FW', 'GK', 'FW', 'DF', 'MF', 'FW,MF', 'FW,DF', 'DF,MF',
#        'MF,DF', 'DF,FW'], dtype=object)

# %% [markdown]
# ### Total Foward Players

# %%
df[df['Position'] == 'FW']
# Out:
#                    Name              Club Nationality Position  Age  Matches  \
# 2           Timo Werner           Chelsea         GER       FW   24       35
# 16        Tammy Abraham           Chelsea         ENG       FW   22       22
# 19       Olivier Giroud           Chelsea         FRA       FW   33       17
# 23   Ruben Loftus-Cheek           Chelsea         ENG       FW   24        1
# 30      Raheem Sterling   Manchester City         ENG       FW   25       31
# ..                  ...               ...         ...      ...  ...      ...
# 516        Oliver Burke  Sheffield United         SCO       FW   23       25
# 518     Oliver McBurnie  Sheffield United         SCO       FW   24       23
# 519      Rhian Brewster  Sheffield United         ENG       FW   20       27
# 523         Billy Sharp  Sheffield United         ENG       FW   34       16
# 526     Daniel Jebbison  Sheffield United         ENG       FW   17        4
#
# ...

# %% [markdown]
# ### No. of unique nationalities

# %%
np.size((df['Nationality'].unique()))
# Out:
# 59

# %% [markdown]
# ### Distribution of Nationalities

# %%
nationality = df.groupby('Nationality').size().sort_values(ascending=False)
nationality.head(10).plot(kind='bar', figsize=(12,6),color=sns.color_palette('magma'))
# Out:
# <AxesSubplot:xlabel='Nationality'>

# %% [markdown]
# ### Clubs with maximum number of players

# %%
df['Club'].value_counts().nlargest(5).plot(kind='bar',color=sns.color_palette('viridis'))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Clubs with least No. of players

# %%
df['Club'].value_counts().nsmallest(5).plot(kind='bar',color=sns.color_palette('viridis'))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Players Based on Age Group

# %%
Under20 = df[df['Age']<= 20]
age20_25 = df[(df['Age']> 20) & (df['Age'] <= 25)]
age25_30 = df[(df['Age']> 25) & (df['Age'] <= 30)]
Above30 = df[df['Age']> 20]

# %%
plt.figure(figsize=(13,6))
x = np.array([Under20['Name'].count(),age20_25['Name'].count(), age25_30['Name'].count(),Above30['Name'].count()])
mylabels = ["<=20",">20 & <=25",">25 & <=30", ">30"]
plt.title("Total players with Age", fontsize=20)
plt.pie(x, labels=mylabels, autopct="%.1f%%")
plt.show()

# %% [markdown]
# ### Players Under 20

# %%
players_under_20 = df[df['Age'] < 20]
players_under_20['Club'].value_counts().plot(kind='bar', color=sns.color_palette('cubehelix'))
# Out:
# <AxesSubplot:>

# %%
players_under_20[players_under_20['Club'] == 'Manchester United']
# Out:
#                    Name               Club Nationality Position  Age  Matches  \
# 61      Mason Greenwood  Manchester United         ENG       FW   18       31
# 72     Brandon Williams  Manchester United         ENG       DF   19        4
# 73          Amad Diallo  Manchester United         CIV       FW   18        3
# 74       Anthony Elanga  Manchester United         SWE       FW   18        2
# 76      Shola Shoretire  Manchester United         ENG       FW   16        2
# 78      Hannibal Mejbri  Manchester United         FRA       MF   17        1
# 79  William Thomas Fish  Manchester United         ENG       DF   17        1
#
#     Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 61      21  1822      7        2               732                   83.1
# 72       2   188      0        0               140                   85.7
# 73       2   166      0        1                64                   84.4
# ...

# %%
players_under_20[players_under_20['Club'] == 'Manchester City']
# Out:
#            Name             Club Nationality Position  Age  Matches  Starts  \
# 47  Eric García  Manchester City         ESP       DF   19        6       3
# 50   Liam Delap  Manchester City         ENG       FW   17        1       0
#
#     Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 47   383      0        0               344                   93.6
# 50    40      0        0                 7                   71.4
#
#     Penalty_Goals  Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards  \
# 47              0                  0  0.03  0.02             0          0
# 50              0                  0  0.06  0.00             0          0
#
#     MinsPerMatch  GoalsPerMatch
# 47            63            0.0
# 50            40            0.0

# %%
players_under_20[players_under_20['Club'] == 'Arsenal']
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 184  Bukayo Saka  Arsenal         ENG    FW,DF   18       32      30  2553
# 203   Martinelli  Arsenal         BRA       FW   19       14       7   589
#
#      Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 184      5        3              1155                   74.9              0
# 203      2        1               159                   79.2              0
#
#      Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards  MinsPerMatch  \
# 184                  0  0.24  0.17             1          0            79
# 203                  0  0.53  0.32             0          0            42
#
#      GoalsPerMatch
# 184       0.156250
# 203       0.142857

# %% [markdown]
# ### Average Age of players per club

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Club',y='Age', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
num_player = df.groupby('Club').size()
data = (df.groupby('Club')['Age'].sum())/num_player
data.sort_values(ascending=False)
# Out:
# Club
# Crystal Palace             28.333333
# West Ham United            27.500000
# Burnley                    27.040000
# West Bromwich Albion       26.766667
# Newcastle United           26.074074
# Manchester City            25.708333
# Tottenham Hotspur          25.625000
# Chelsea                    25.592593
# Leicester City             25.592593
# Liverpool FC               25.571429
# Everton                    25.413793
# Leeds United               25.347826
# Fulham                     25.035714
# Arsenal                    24.965517
# Sheffield United           24.814815
# Brighton                   24.555556
# Wolverhampton Wanderers    24.444444
# Aston Villa                24.291667
# Southampton                24.137931
# Manchester United          23.862069
# dtype: float64

# %%
Assists_by_club = pd.DataFrame(df.groupby('Club', as_index=False)['Assists'].sum())
sns.set_theme(style='whitegrid',color_codes=True)
ax = sns.barplot(x='Club',y='Assists', data=Assists_by_club.sort_values(by='Assists'),palette='Set2')
ax.set_xlabel('Club',fontsize=30)
ax.set_ylabel('Assists',fontsize=20)
plt.xticks(rotation=75)
plt.rcParams['figure.figsize'] = (20,8)
plt.title('Clubs vs Assists', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Clubs vs Assists')

# %%
top_10_assists = df[['Name','Club','Assists','Matches']].nlargest(n=10,columns='Assists')
top_10_assists
# Out:
#                      Name               Club  Assists  Matches
# 162            Harry Kane  Tottenham Hotspur       14       35
# 34        Kevin De Bruyne    Manchester City       12       25
# 51        Bruno Fernandes  Manchester United       12       37
# 161         Son Heung-min  Tottenham Hotspur       10       37
# 273         Jack Grealish        Aston Villa       10       26
# 54        Marcus Rashford  Manchester United        9       37
# 110           Jamie Vardy     Leicester City        9       34
# 220  Raphael Dias Belloli       Leeds United        9       30
# 2             Timo Werner            Chelsea        8       35
# 136       Aaron Cresswell    West Ham United        8       36

# %%
Goals_by_clubs = pd.DataFrame(df.groupby('Club',as_index=False)['Goals'].sum())
sns.set_theme(style='whitegrid',color_codes=True)
ax = sns.barplot(x='Club',y='Goals',data=Goals_by_clubs.sort_values(by='Goals'),palette='rocket')
ax.set_xlabel('Club',fontsize=20)
ax.set_ylabel('Goals',fontsize=20)
plt.xticks(rotation=75)
plt.rcParams['figure.figsize'] = (20,8)
plt.title('Clubs vs Goals',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Clubs vs Goals')

# %% [markdown]
# ### Top Goal Scorers

# %%
top_10_scorers = df[['Name','Club','Matches','Goals']].nlargest(n=10,columns='Goals')
top_10_scorers
# Out:
#                       Name               Club  Matches  Goals
# 162             Harry Kane  Tottenham Hotspur       35     23
# 81           Mohamed Salah       Liverpool FC       37     22
# 51         Bruno Fernandes  Manchester United       37     18
# 161          Son Heung-min  Tottenham Hotspur       37     17
# 214        Patrick Bamford       Leeds United       38     17
# 237  Dominic Calvert-Lewin            Everton       33     16
# 110            Jamie Vardy     Leicester City       34     15
# 267          Ollie Watkins        Aston Villa       37     14
# 33          İlkay Gündoğan    Manchester City       28     13
# 191    Alexandre Lacazette            Arsenal       31     13

# %% [markdown]
# ### Goals Per Match

# %%
goals_per_match = df[['Name','Club','Matches','Goals','GoalsPerMatch']].nlargest(n=10,columns='Goals')
goals_per_match
# Out:
#                       Name               Club  Matches  Goals  GoalsPerMatch
# 162             Harry Kane  Tottenham Hotspur       35     23       0.657143
# 81           Mohamed Salah       Liverpool FC       37     22       0.594595
# 51         Bruno Fernandes  Manchester United       37     18       0.486486
# 161          Son Heung-min  Tottenham Hotspur       37     17       0.459459
# 214        Patrick Bamford       Leeds United       38     17       0.447368
# 237  Dominic Calvert-Lewin            Everton       33     16       0.484848
# 110            Jamie Vardy     Leicester City       34     15       0.441176
# 267          Ollie Watkins        Aston Villa       37     14       0.378378
# 33          İlkay Gündoğan    Manchester City       28     13       0.464286
# 191    Alexandre Lacazette            Arsenal       31     13       0.419355

# %% [markdown]
# ### Goals with Assists vs Goals without Assists

# %%
plt.figure(figsize=(14,7))
assists = df['Assists'].sum()
data = [Total_Goals - assists, assists]
labels = ['Goals Without Assists','Goals With Assists']
color = sns.color_palette('Set1')
plt.pie(data,labels=labels,colors=color,autopct='%.0f%%')
plt.show()

# %% [markdown]
# ### Top 10 players with most yellow cards

# %%
epl_yellow = df.sort_values(by='Yellow_Cards', ascending=False)[:10]
plt.figure(figsize=(20,6))
plt.title('Players with most yellow cards')
c = sns.barplot(x=epl_yellow['Name'], y = epl_yellow['Yellow_Cards'], label='Players',color='Yellow')
plt.ylabel('Number of Yellow Cards')
c.set_xticklabels(c.get_xticklabels(),rotation=45)
c
# Out:
# <AxesSubplot:title={'center':'Players with most yellow cards'}, xlabel='Name', ylabel='Number of Yellow Cards'>
